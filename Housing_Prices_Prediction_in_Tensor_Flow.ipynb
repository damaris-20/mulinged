# %% [markdown]
# <a href="https://colab.research.google.com/github/damaris-20/mulinged/blob/main/Housing_Prices_Prediction_in_Tensor_Flow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **HOUSING PRICES PREDICTION**
#
#
# ```
# # This is formatted as code
# ```

# %%
import numpy as np
import tensorflow as tf

# %%
import unittest

# %%
# GRADED FUNCTION: create_training_data

def create_training_data():
    n_bedrooms = None
    price_in_hundreds_of_thousands = None
    return n_bedrooms, price_in_hundreds_of_thousands

# %%
def create_training_data():
    # Example: generate random features and targets
    features = np.random.rand(100, 5)  # 100 samples, 5 features
    targets = np.random.rand(100, 1)   # 100 samples, 1 target

    return features, targets

# %%
features, targets = create_training_data()
if features is None or targets is None:
    print("Error: features or targets are None")
else:
    print(f"Features have shape: {features.shape}")
    print(f"Targets have shape: {targets.shape}")
# Out:
# Features have shape: (100, 5)
# Targets have shape: (100, 1)

# %%
def create_training_data():
    features = np.random.rand(6)
    targets = np.random.rand(6)

    return features, targets
features, targets = create_training_data()
print(f"Features have shape: {features.shape}")
print(f"Targets have shape: {targets.shape}")
# Out:
# Features have shape: (6,)
# Targets have shape: (6,)

# %%
def create_training_data():
    features = np.array([1, 2, 3, 4, 5, 6])
    targets = np.array([10, 20, 30, 40, 50, 60])
    return features, targets
class TestCreateTrainingData(unittest.TestCase):

    def test_create_training_data(self):
        features, targets = create_training_data()

        self.assertEqual(features.shape, (6,))
        self.assertEqual(targets.shape, (6,))
        np.testing.assert_array_equal(features, np.array([1, 2, 3, 4, 5, 6]))
        np.testing.assert_array_equal(targets, np.array([10, 20, 30, 40, 50, 60]))

# %% [markdown]
# # **define_and_compile_model**

# %%
import tensorflow as tf

def define_and_compile_model():

    model = tf.keras.Sequential([
        tf.keras.Input(shape=(1,)),

        # Define a Dense layer with 1 unit (for output) and no activation (linear output)
        tf.keras.layers.Dense(units=1)
    ])

    # Compile your model with the SGD optimizer and mean squared error as the loss function
    model.compile(optimizer='sgd', loss='mean_squared_error')

    return model
model = define_and_compile_model()

print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 1)                   │               2 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# # **train_model**

# %%
def train_model():

    n_bedrooms, price_in_hundreds_of_thousands = None

    model.fit(None, None, epochs=None)

    return model

# %%
 trained_model = train_model()
def train_model():
    n_bedrooms, price_in_hundreds_of_thousands = create_training_data()

    model = define_and_compile_model()

    import numpy as np
    n_bedrooms = np.array(n_bedrooms)
    price_in_hundreds_of_thousands = np.array(price_in_hundreds_of_thousands)

    model.fit(n_bedrooms, price_in_hundreds_of_thousands, epochs=500)

    return model
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - loss: 1828.5702
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 846.9203
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 392.5788
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 182.2915
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 84.9601
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 39.9078
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 19.0520
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.3951
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.9213
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.8466
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.8822
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 1.4317
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.2191
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1167
# Epoch 15/500
# ...

# %%
new_n_bedrooms = np.array([7.0])
predicted_price = trained_model.predict(new_n_bedrooms, verbose=False).item()
print(f"Your model predicted a price of {predicted_price:.2f} hundreds of thousands of dollars for a {int(new_n_bedrooms.item())} bedrooms house")
# Out:
# Your model predicted a price of 69.75 hundreds of thousands of dollars for a 7 bedrooms house

# %% [markdown]
# prediction value very close to 4
